# %% [markdown]
# # Représenter une fonction
#
# Des liens intéressants :
#
# http://www.python-simple.com/python-matplotlib/pyplot.php
#
# http://www.courspython.com/introduction-courbes.html

# %%
from math import * # inutile dans cette aide
from random import * #inutile dans cette aide
import matplotlib.pyplot as plt
import numpy as np 


def f(x):
    return(x**2)


lx= np.linspace(-5,5,100) #créer une liste de 100 valeurs dans l'intervalle[-5,5]
plt.plot(lx,f(lx))
plt.axis([-5, 5, -4, 25])
plt.show()
