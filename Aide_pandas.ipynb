# %% [markdown]
# # Utilisation de la bibliothèque pandas pour gérer des séries statistiques.

# %%
# -*- coding: utf-8 -*-


import pandas as pd
df = pd.read_excel('donnees_lancer.xlsx')
df.head()
# Out:
#    Lancer dé n°1  Lancer dé n°2  Somme  Produit
# 0              3              1      4        3
# 1              6              4     10       24
# 2              4              5      9       20
# 3              1              6      7        6
# 4              4              5      9       20

# %%
len(df)
# Out:
# 199

# %%
df.columns
# Out:
# Index(['Lancer dé n°1', 'Lancer dé n°2', 'Somme', 'Produit'], dtype='object')

# %%
df.describe()
# Out:
#        Lancer dé n°1  Lancer dé n°2       Somme     Produit
# count     199.000000     199.000000  199.000000  199.000000
# mean        3.492462       3.361809    6.854271   11.798995
# std         1.774879       1.684675    2.470813    8.771499
# min         1.000000       1.000000    2.000000    1.000000
# 25%         2.000000       2.000000    5.000000    4.000000
# 50%         4.000000       3.000000    7.000000   10.000000
# 75%         5.000000       5.000000    9.000000   18.000000
# max         6.000000       6.000000   12.000000   36.000000

# %%
df2 = pd.read_excel('ensemble.xlsx',header=7,sheetname=0)
df2.head(10)
# Out:
#    Code région         Nom de la région  Nombre d'arrondissements  \
# 0           84     Auvergne-Rhône-Alpes                        39
# 1           27  Bourgogne-Franche-Comté                        24
# 2           53                 Bretagne                        15
# 3           24      Centre-Val de Loire                        20
# 4           94                    Corse                         5
# 5           44                Grand-Est                        39
# 6            1               Guadeloupe                         2
# 7            3                   Guyane                         2
# 8           32          Hauts-de-France                        26
# 9           11            Île-de-France                        25
#
#    Nombre de cantons  Nombre de communes  Population municipale  \
# 0              242.0                4133                7820966
# 1              152.0                3777                2820623
# 2              102.0                1250                3276543
# 3              102.0                1811                2577435
# 4               26.0                 360                 324212
# 5              200.0                5152                5554645
# 6               21.0                  32                 400186
# 7                NaN                  22                 252338
# 8              145.0                3818                6006156
# 9              155.0                1278               12027565
#
#    Population totale  Unnamed: 7
# 0            8016878         NaN
# 1            2906361         NaN
# 2            3377195         NaN
# 3            2647698         NaN
# 4             329599         NaN
# 5            5679943         NaN
# 6             406706         NaN
# 7             254845         NaN
# 8            6114617         NaN
# 9           12179602         NaN

# %%
df2.describe()
# Out:
#        Code région  Nombre d'arrondissements  Nombre de cantons  \
# count    17.000000                 17.000000          15.000000
# mean     41.352941                 19.647059         136.066667
# std      33.151058                 13.522856          77.739002
# min       1.000000                  2.000000          21.000000
# 25%      11.000000                  5.000000         102.000000
# 50%      32.000000                 18.000000         131.000000
# 75%      75.000000                 26.000000         177.500000
# max      94.000000                 41.000000         258.000000
#
#        Nombre de communes  Population municipale  Population totale  \
# count           17.000000           1.700000e+01       1.700000e+01
# mean          2109.882353           3.876892e+06       3.962235e+06
# std           1850.861721           3.169716e+06       3.223544e+06
# min             22.000000           2.523380e+05       2.548450e+05
# 25%            360.000000           8.427670e+05       8.526570e+05
# 50%           1357.000000           3.335645e+06       3.424021e+06
# 75%           3818.000000           5.730753e+06       5.872219e+06
# max           5152.000000           1.202756e+07       1.217960e+07
#
#        Unnamed: 7
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN
